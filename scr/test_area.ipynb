# %%
import util.generator as generator

# %%
generator.brown_generator([9,107], 1, t=10.0, delta=0.1, data_type="json")
# Out:
# {'latitude': 8.288184217439891,
#  'longitude': 107.39387045324658,
#  'sound': 42.15019788259803,
#  'temperature': 20.464104263303028,
#  'altitude': 1833.3899512950231,
#  'event_ts': 1770901665229,
#  'id': 'ids_1770901665229'}

# %%
generator.brown_generator_location([9,107], 1, t=10.0, delta=0.1, data_type="json")
# Out:
# {'latitude': 8.79348001198923,
#  'longitude': 107.564525625918,
#  'event_ts': 1770901666881,
#  'id': 'ids_1770901666881'}

# %%
generator.brown_generator_status( 1, data_type="json")
# Out:
# {'sound': 47.36262743549777,
#  'temperature': 21.37502720530026,
#  'altitude': 1029.6092916183948,
#  'event_ts': 1770901669727,
#  'id': 'ids_1770901669727'}
